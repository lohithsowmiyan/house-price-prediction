# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
load_boston = load_boston()
print(load_boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(load_boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
new_boston_col=[]
new_boston_val=[]
for col in df.feature_names:
    new_boston_col.append(col)
for val in df.target:
    new_boston_val.append(val)

# %%
x= load_boston.data
y=load_boston.target

df = pd.DataFrame(x,columns=load_boston.feature_names)
df.head(500)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 495  0.17899   0.0   9.69   0.0  0.585  5.670  28.8  2.7986  6.0  391.0
# 496  0.28960   0.0   9.69   0.0  0.585  5.390  72.9  2.7986  6.0  391.0
# 497  0.26838   0.0   9.69   0.0  0.585  5.794  70.6  2.8927  6.0  391.0
# 498  0.23912   0.0   9.69   0.0  0.585  6.019  65.3  2.4091  6.0  391.0
# 499  0.17783   0.0   9.69   0.0  0.585  5.569  73.5  2.3999  6.0  391.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df['Sales_price']=y
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Sales_price
# 0       15.3  396.90   4.98         24.0
# ...

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x='CRIM', y='Sales_price',hue='RM',data=df,color='red')
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='Sales_price'>

# %%
sns.scatterplot(x='CRIM', y='Sales_price',hue='B',data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='CRIM', ylabel='Sales_price'>

# %%
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,ax=ax)
# Out:
# <AxesSubplot:>

# %%
df['Sales_price'] = np.log1p(df['Sales_price'])
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Sales_price
# 0       15.3  396.90   4.98     1.439569
# ...

# %%
cor = df.corr()
cor_target = abs(cor['Sales_price'])
clean = cor_target[cor_target>0.2]
column = [index for index,val in clean.iteritems()]
column.remove('Sales_price')
column
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PTRATIO',
#  'B',
#  'LSTAT']

# %%
ndf = df.drop(columns=['CHAS'])
ndf
# Out:
#         CRIM    ZN  INDUS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0    0.00632  18.0   2.31  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1    0.02731   0.0   7.07  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2    0.02729   0.0   7.07  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3    0.03237   0.0   2.18  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4    0.06905   0.0   2.18  0.458  7.147  54.2  6.0622  3.0  222.0     18.7
# ..       ...   ...    ...    ...    ...   ...     ...  ...    ...      ...
# 501  0.06263   0.0  11.93  0.573  6.593  69.1  2.4786  1.0  273.0     21.0
# 502  0.04527   0.0  11.93  0.573  6.120  76.7  2.2875  1.0  273.0     21.0
# 503  0.06076   0.0  11.93  0.573  6.976  91.0  2.1675  1.0  273.0     21.0
# 504  0.10959   0.0  11.93  0.573  6.794  89.3  2.3889  1.0  273.0     21.0
# 505  0.04741   0.0  11.93  0.573  6.030  80.8  2.5050  1.0  273.0     21.0
#
#           B  LSTAT  Sales_price
# 0    396.90   4.98     1.439569
# ...

# %%
from sklearn.model_selection import train_test_split
x=ndf.drop('Sales_price',axis=1)
y=ndf['Sales_price']



x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(x_test)
# Out:
#          CRIM    ZN  INDUS    NOX     RM    AGE     DIS   RAD    TAX  PTRATIO  \
# 294   0.08199   0.0  13.92  0.437  6.009   42.3  5.5027   4.0  289.0     16.0
# 103   0.21161   0.0   8.56  0.520  6.137   87.4  2.7147   5.0  384.0     20.9
# 357   3.84970   0.0  18.10  0.770  6.395   91.0  2.5052  24.0  666.0     20.2
# 32    1.38799   0.0   8.14  0.538  5.950   82.0  3.9900   4.0  307.0     21.0
# 165   2.92400   0.0  19.58  0.605  6.101   93.0  2.2834   5.0  403.0     14.7
# ..        ...   ...    ...    ...    ...    ...     ...   ...    ...      ...
# 17    0.78420   0.0   8.14  0.538  5.990   81.7  4.2579   4.0  307.0     21.0
# 383   7.99248   0.0  18.10  0.700  5.520  100.0  1.5331  24.0  666.0     20.2
# 501   0.06263   0.0  11.93  0.573  6.593   69.1  2.4786   1.0  273.0     21.0
# 437  15.17720   0.0  18.10  0.740  6.152  100.0  1.9142  24.0  666.0     20.2
# 269   0.09065  20.0   6.96  0.464  5.920   61.5  3.9175   3.0  223.0     18.6
#
#           B  LSTAT
# ...

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = lr.predict(x_test)
print ("ACTUAL VALUE" ,y_test[501])
print ("PREDICTED VALUE" ,prediction[0])
# Out:
# ACTUAL VALUE 1.4237673995086404
# PREDICTED VALUE 1.4500442789607035
